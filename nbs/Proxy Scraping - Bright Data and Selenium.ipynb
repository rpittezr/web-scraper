# %%
url = "https://www.amazon.com.br/Barra-Prote%C3%ADna-BOLD-Snacks-Pistache/dp/B0DGV6JZ7R/ref=sr_1_14?adgrpid=151629488322&dib=eyJ2IjoiMSJ9.I3E84OD32q93Y5kYtWF4k8lBLPsfwhwhtdzGuA1kYX1g_x_bD2osEVv6fWeqpUhhm-D5d89o90hb5VMCUUdmc3gE79zpt-XHTIsoRbWljE2gQ1tZWYWzAbLEuMdZ4RDzL3GVcSJTTdHDTYN3SfLuEzJlPB68NdwjHpy9ap9QArslvA1kZUjtqZQ1hU14VIRTUZmoZAxr9OsB2A12w5z867-qfdDoZorxMY6-pTu56N__P03MTbdgTleQZqOWLLQswLE3adcgKszqdY-VfBy3LIsA2ew9IKQKi6BswioqY4c.2VN8gO-bQhJ_c89uuTP8dPlNvUZspHHc67twESbmcHs&dib_tag=se&gad_source=1&hvadid=661320038394&hvdev=c&hvlocphy=9100475&hvnetw=g&hvqmt=b&hvrand=17417826114276119993&hvtargid=kwd-2205393815431&hydadcr=8963_13561382&keywords=bold+barra+de+proteina+12g&qid=1731199066&sr=8-14&ufe=app_do%3Aamzn1.fos.a492fd4a-f54d-4e8d-8c31-35e0a04ce61e"

# %%
from selenium.webdriver import Remote, ChromeOptions
from selenium.webdriver.chromium.remote_connection import ChromiumRemoteConnection

SBR_WEBDRIVER = 'https://brd-customer-hl_6796b9d2-zone-scraping_browser1:o21grzjushh5@brd.superproxy.io:9515'


def scrape(url=None):
    print('Connecting to Scraping Browser...')
    sbr_connection = ChromiumRemoteConnection(SBR_WEBDRIVER, 'goog', 'chrome')
    html = ""
    with Remote(sbr_connection, options=ChromeOptions()) as driver:
        print(f'Connected! Navigating to {url}')
        driver.get(url)
        # CAPTCHA handling: If you're expecting a CAPTCHA on the target page, use the following code snippet to check the status of Scraping Browser's automatic CAPTCHA solver
        # print('Waiting captcha to solve...')
        # solve_res = driver.execute('executeCdpCommand', {
        #     'cmd': 'Captcha.waitForSolve',
        #     'params': {'detectTimeout': 10000},
        # })
        # print('Captcha solve status:', solve_res['value']['status'])
        print('Navigated! Scraping page content...')
        html = driver.page_source
    return html

# %%
scrape(url=url)
# Out:
# Connecting to Scraping Browser...
# Connected! Navigating to https://www.amazon.com.br/Barra-Prote%C3%ADna-BOLD-Snacks-Pistache/dp/B0DGV6JZ7R/ref=sr_1_14?adgrpid=151629488322&dib=eyJ2IjoiMSJ9.I3E84OD32q93Y5kYtWF4k8lBLPsfwhwhtdzGuA1kYX1g_x_bD2osEVv6fWeqpUhhm-D5d89o90hb5VMCUUdmc3gE79zpt-XHTIsoRbWljE2gQ1tZWYWzAbLEuMdZ4RDzL3GVcSJTTdHDTYN3SfLuEzJlPB68NdwjHpy9ap9QArslvA1kZUjtqZQ1hU14VIRTUZmoZAxr9OsB2A12w5z867-qfdDoZorxMY6-pTu56N__P03MTbdgTleQZqOWLLQswLE3adcgKszqdY-VfBy3LIsA2ew9IKQKi6BswioqY4c.2VN8gO-bQhJ_c89uuTP8dPlNvUZspHHc67twESbmcHs&dib_tag=se&gad_source=1&hvadid=661320038394&hvdev=c&hvlocphy=9100475&hvnetw=g&hvqmt=b&hvrand=17417826114276119993&hvtargid=kwd-2205393815431&hydadcr=8963_13561382&keywords=bold+barra+de+proteina+12g&qid=1731199066&sr=8-14&ufe=app_do%3Aamzn1.fos.a492fd4a-f54d-4e8d-8c31-35e0a04ce61e
# Navigated! Scraping page content...
# ...
